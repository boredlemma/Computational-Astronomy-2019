# %% [markdown]
# # 3장 파이썬 문법 미리 알아두기
#
#
# ## 3 들여쓰기
# #### 들여쓰기를 할 때는 빈칸 네 개 또는 탭을 한 번 입력하면 된다. 혼용할 경우 오류가 발생한다. 파이썬은 빈 공간에 민감하기 때문에 빈칸 하나, 탭 한 번도 주의해서 사용해야 한다.
#
#
# ## 4 연산
# #### 빼기와 나누기를 연산자를 문자열에 적용하면 TypeError가 생긴다.
#
#
# ## 5 변수와 변수 연산
# #### 변수 이름을 만들 때, 문자와 숫자를 조합할 수는 있지만 숫자로 시작할 수는 없다. 영문 대소문자를 구분한다.
#
#
# ## 6 출력 방식과 출력 형식
# #### 두 가지 출력 형식 : 텍스트 형식과 대표 형식
# #### 텍스트 형식: print() 함수를 사용, 쉼표로 분리해 넣어주면 객체 사이에 공백이 추가되어 출력
# #### 대표 형식: 해당 개체를 대표하는 형식으로 출력
# #### 예: 문자열을 대표 형식으로 출력하면 '문자열', 텍스트 형식으로 출력하면 문자열
#
#
# ## 7 사용자 키보드 입력
# #### 대표적으로 input()함수, 이를 통해 입력받은 값은 모두 문자열
#
#
# ## 8 형변환
# #### 변수의 자료형이 같은 경우에만 연산을 실행할 수 있다. 형변환(type casting)이란 어떤 자료형을 다른 자료형으로 변환하는 과정.
# #### str() 문자열, int() 정수, float() 실수
#
#
# ## 9 주석 작성하기
# #### 주석을 잘 작성하면 코드를 이해하기 편하다. 처음부터 중요한 사항이나 설명을 주석으로 작성하는 습관을 기르자.

# %% [markdown]
# # 4장 식별자와 예약어
# ## 1 파이썬 프로그램을 구성하는 요소
# #### 식별자(identifier, 변수, 함수 등을 구별하기 위해 붙이는 이름)와 리터럴(literal, 쓰여있는 그대로의 값 그 자체)
# #### 표현식(expression, 새로운 값을 생성하거나 계산하는 코드 조각)
# #### 명령문(statement, 특정한 작업을 실행하는 코드 전체)
# #### 표현식은 값을 생성하는 일부분, 명령문은 특정 작업을 싫애하는 코드 전체
# #### 표현식과 명령문이 모여 함수를 구성
# #### 모듈(연관있는 함수나 클래스를 담은 py파일.)
# #### 프로그램(모듈이나 함수를 활용해서 특정 작업을 실행하는 단위)
# #### 패키지(프로그램과 모듈을 모아놓은 것)
# #### 라이브러리(패키지의 묶음)
# ## 2 식별자
# #### 식별자는 객체에 붙여진 이름이긴 하나 객체의 데이터를 저장한 것은 아님. 객체의 위치를 참조하기 위해 부여한 고유한 이름.
# #### hex(id())함수를 이용하여 고유번호를 알 수 있다.
# #### 단, 객체를 할당하지 않은 식별자는 사용할 수 없다.
# #### 파이썬 예약어는 식별자로 사용할 수 없다. 밑줄은 사용할 수 있지만 마이너스 부호는 사용할 수 없다. 밑줄을 단어의 시작과 끝, 또는 단독으로 사용하는 것은 피한다.따옴표도 사용할 수 없다.
# ## 3 예약어
# #### 예약어란 키워드로 사용하기 위해 예약한 단어. 대소문자는 구분.
# #### help('keywords')를 입력하면 확인 가능

# %% [markdown]
# # 5장 기본자료형
# ## 1 자료형 개요
# #### 불변자료형(불린(True/False), 정수, 실수, 문자열, 튜플), 가변자료형(리스트, 딕셔너리, 세트)
# #### 기본자료형(불린,숫자,문자열),복합자료형(시퀀스형(리스트,튜플),매핑형(딕셔너리),집합형(세트))
# #### type()클래스로 자료형 확인
# ## 2 불린
# #### True=1, False=0이라서 숫자형으로 분류되기도 함
# #### 거짓: False, 0, 0.0, None, 빈 문자열(' '), 빈 복합자료형([ ], ( ), { }, set())
# #### 참: 그 외 나머지
# #### bool() : 참/거짓 검증하는 클래스
# #### 비교연산자(<,>,==,!=,<=,>=), 논리연산자(and, or, not)
# #### 논리연산자의 우선순위: 괄호 > not > and > or
# ## 3 숫자형
# ### int
# #### / : 실수 나누기 연산자
# #### // : 정수 나누기 연산자 (몫만 구함)
# #### % : 나머지 구하는 연산자
# #### ** : 거듭제곱 연산자
# ### float : 실수, 부동소수점수
# #### 지수표현범 : 7.9e-4=0.00079
# ### 자주 사용하는 함수
# #### divmod(x,y) : 몫과 나머지, 총 두 개의 정수를 반환
# #### pow(x,y)=x**y, pow(x,y,z)=x**y%z
# #### round() : 반올림, 정수면 정수 반환 실수면 실수 반환
# ### 기타 숫자형
# #### 소수는 decimal 모듈의 Decimal 클래스를 불러와 사용할 수 있으며(from decimal import Decimal), 실수보다 정확히 계산할 수 있지만 느리다.
# #### 분수는 (from fractions import Fraction) 유리수를 계산할 때 유용
# #### 복소수는 3+5j의 형태. real과 imag라는 속성이 있음
# ## 4 문자열
# #### '' 또는 "" 중 하나를 택해서 일관성있게 적용하면 된다.
# #### 중첩 따옴표를 넣어야 할 때: 1. '' 안에는 "", "" 안에는 '' 2. 이스케이프 문자인 역슬래시 \ 사용
# #### 그러나 \ 사용은 가독성을 떨어트리기에 사용 자제 권장
# #### 삼중 따옴표라는 것도 있음
# #### 이스케이프 문자는 바로 다음에 따라나오는 문자를 원래 의미가 아닌 특별한 의미로 처리해야 할 때 사용. 탈출 코드라고도 함.
# #### \n (새줄바꿈, 개행문자) \t (tab으로 처리) \\n(일반문자 \n으로 처리)
# #### 문자열을 나타내는 첫 따옴표 앞에 r을 넣어주면 모든 문자를 있는 그대로 인식한다.(raw string)
# ### whitespace
# #### 화면상에는 표시하지 않지만 컴퓨터 모니터나 프린터와 같은 출력장치를 제어하는 문자
# #### 공백문자' ' 새줄바꿈\n 탭\t 캐리지 리턴 \r 수직탭 \v 페이지 넘기기 \f

# %%
import string
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %% [markdown]
# ### 줄계속
# #### 특정 코드를 한 줄로 인식하게 하면서 실제로는 여러 줄에 나누어 작성하는 방법 : 1. 소괄호 사용 2. \를 각 줄 맨 마지막에 추가해서 줄바꿈을 탈출 -> 소괄호 권장
# #### 문자열의 길이를 구하는 함수: len()
# #### 인덱스는 0부터 시작 [-1]은 항상 마지막 문자
# #### 문자열 분할 연산자 :  문자열[시작번호 : 끝번호:폭] 이 떄 폭의 숫자가 음수라면 뒤쪽 끝에서 출발하여 앞쪽으로 폭만큼 건너뛰면서 문자 추출
